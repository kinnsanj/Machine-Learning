# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Google Stocks.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 7s 97ms/step - loss: 0.0056 - mean_absolute_error: 0.0522 - val_loss: 0.0180 - val_mean_absolute_error: 0.1064
# Epoch 2/100
# 28/28 [==============================] - 2s 61ms/step - loss: 6.9104e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0116 - val_mean_absolute_error: 0.0832
# Epoch 3/100
# 28/28 [==============================] - 2s 60ms/step - loss: 5.0169e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0076 - val_mean_absolute_error: 0.0670
# Epoch 4/100
# 28/28 [==============================] - 2s 86ms/step - loss: 4.5113e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0063 - val_mean_absolute_error: 0.0597
# Epoch 5/100
# 28/28 [==============================] - 2s 75ms/step - loss: 4.8736e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0090 - val_mean_absolute_error: 0.0756
# Epoch 6/100
# 28/28 [==============================] - 2s 60ms/step - loss: 4.2682e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0053 - val_mean_absolute_error: 0.0545
# Epoch 7/100
# 28/28 [==============================] - 2s 60ms/step - loss: 4.3026e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0048 - val_mean_absolute_error: 0.0524
# Epoch 8/100
# 28/28 [==============================] - 2s 61ms/step - loss: 4.4246e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0053 - val_mean_absolute_error: 0.0558
# Epoch 9/100
# 28/28 [==============================] - 2s 61ms/step - loss: 4.1375e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0055 - val_mean_absolute_error: 0.0578
# Epoch 10/100
# 28/28 [==============================] - 2s 66ms/step - loss: 4.1909e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0071 - val_mean_absolute_error: 0.0676
# Epoch 11/100
# 28/28 [==============================] - 2s 90ms/step - loss: 3.6872e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0060 - val_mean_absolute_error: 0.0611
# Epoch 12/100
# 28/28 [==============================] - 2s 73ms/step - loss: 3.5334e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0069 - val_mean_absolute_error: 0.0672
# Epoch 13/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.6817e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0068 - val_mean_absolute_error: 0.0667
# Epoch 14/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.5435e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0055 - val_mean_absolute_error: 0.0592
# Epoch 15/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.1905e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0028 - val_mean_absolute_error: 0.0400
# Epoch 16/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.1107e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0054 - val_mean_absolute_error: 0.0594
# Epoch 17/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.0776e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0058 - val_mean_absolute_error: 0.0613
# Epoch 18/100
# 28/28 [==============================] - 2s 88ms/step - loss: 3.0879e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0030 - val_mean_absolute_error: 0.0417
# Epoch 19/100
# 28/28 [==============================] - 2s 72ms/step - loss: 3.1222e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0038 - val_mean_absolute_error: 0.0481
# Epoch 20/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.9443e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0046 - val_mean_absolute_error: 0.0539
# Epoch 21/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.7329e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0036 - val_mean_absolute_error: 0.0468
# Epoch 22/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.5346e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0059 - val_mean_absolute_error: 0.0634
# Epoch 23/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.2867e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0021 - val_mean_absolute_error: 0.0346
# Epoch 24/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.8178e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0036 - val_mean_absolute_error: 0.0468
# Epoch 25/100
# 28/28 [==============================] - 3s 92ms/step - loss: 2.8102e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0078 - val_mean_absolute_error: 0.0748
# Epoch 26/100
# 28/28 [==============================] - 2s 71ms/step - loss: 2.6585e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0036 - val_mean_absolute_error: 0.0476
# Epoch 27/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.5352e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0016 - val_mean_absolute_error: 0.0290
# Epoch 28/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.0023e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0045 - val_mean_absolute_error: 0.0556
# Epoch 29/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.3499e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0027 - val_mean_absolute_error: 0.0412
# Epoch 30/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.4062e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0024 - val_mean_absolute_error: 0.0370
# Epoch 31/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.3483e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0019 - val_mean_absolute_error: 0.0316
# Epoch 32/100
# 28/28 [==============================] - 3s 98ms/step - loss: 2.2892e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0019 - val_mean_absolute_error: 0.0324
# Epoch 33/100
# 28/28 [==============================] - 2s 71ms/step - loss: 2.3462e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0019 - val_mean_absolute_error: 0.0320
# Epoch 34/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.0473e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0034 - val_mean_absolute_error: 0.0472
# Epoch 35/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.1056e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0033 - val_mean_absolute_error: 0.0456
# Epoch 36/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.9689e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0022 - val_mean_absolute_error: 0.0344
# Epoch 37/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.0045e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0014 - val_mean_absolute_error: 0.0269
# Epoch 38/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.8254e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0025 - val_mean_absolute_error: 0.0387
# Epoch 39/100
# 28/28 [==============================] - 3s 99ms/step - loss: 1.9489e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0024 - val_mean_absolute_error: 0.0370
# Epoch 40/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.8500e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0029 - val_mean_absolute_error: 0.0402
# Epoch 41/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.6387e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0035 - val_mean_absolute_error: 0.0461
# Epoch 42/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.7783e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0032 - val_mean_absolute_error: 0.0446
# Epoch 43/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.8309e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0031 - val_mean_absolute_error: 0.0445
# Epoch 44/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.6958e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0020 - val_mean_absolute_error: 0.0313
# Epoch 45/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.6032e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0012 - val_mean_absolute_error: 0.0231
# Epoch 46/100
# 28/28 [==============================] - 2s 89ms/step - loss: 1.8941e-04 - mean_absolute_error: 0.0101 - val_loss: 9.8873e-04 - val_mean_absolute_error: 0.0221
# Epoch 47/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.8071e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0018 - val_mean_absolute_error: 0.0292
# Epoch 48/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.6001e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0033 - val_mean_absolute_error: 0.0475
# Epoch 49/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.7979e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0044 - val_mean_absolute_error: 0.0554
# Epoch 50/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.7373e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0023 - val_mean_absolute_error: 0.0379
# Epoch 51/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.4430e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0038 - val_mean_absolute_error: 0.0501
# Epoch 52/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.4416e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0038 - val_mean_absolute_error: 0.0489
# Epoch 53/100
# 28/28 [==============================] - 2s 85ms/step - loss: 1.5936e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0023 - val_mean_absolute_error: 0.0376
# Epoch 54/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.4112e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0025 - val_mean_absolute_error: 0.0403
# Epoch 55/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.3800e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0018 - val_mean_absolute_error: 0.0305
# Epoch 56/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.4230e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0011 - val_mean_absolute_error: 0.0222
# Epoch 57/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.3081e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0022 - val_mean_absolute_error: 0.0340
# Epoch 58/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.3283e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0013 - val_mean_absolute_error: 0.0234
# Epoch 59/100
# 28/28 [==============================] - 2s 81ms/step - loss: 1.4217e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0024 - val_mean_absolute_error: 0.0376
# Epoch 60/100
# 28/28 [==============================] - 2s 82ms/step - loss: 1.2644e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0015 - val_mean_absolute_error: 0.0279
# Epoch 61/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.2953e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0022 - val_mean_absolute_error: 0.0329
# Epoch 62/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.4359e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0013 - val_mean_absolute_error: 0.0236
# Epoch 63/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.2240e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0012 - val_mean_absolute_error: 0.0237
# Epoch 64/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.2072e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0017 - val_mean_absolute_error: 0.0322
# Epoch 65/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.4563e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0024 - val_mean_absolute_error: 0.0399
# Epoch 66/100
# 28/28 [==============================] - 2s 83ms/step - loss: 1.3849e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0016 - val_mean_absolute_error: 0.0295
# Epoch 67/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.3635e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0021 - val_mean_absolute_error: 0.0352
# Epoch 68/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.5216e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0027 - val_mean_absolute_error: 0.0383
# Epoch 69/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.2279e-04 - mean_absolute_error: 0.0080 - val_loss: 8.9786e-04 - val_mean_absolute_error: 0.0192
# Epoch 70/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.1995e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0014 - val_mean_absolute_error: 0.0257
# Epoch 71/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.1638e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0011 - val_mean_absolute_error: 0.0220
# Epoch 72/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.2239e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0011 - val_mean_absolute_error: 0.0223
# Epoch 73/100
# 28/28 [==============================] - 2s 90ms/step - loss: 1.0767e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0016 - val_mean_absolute_error: 0.0261
# Epoch 74/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.2929e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0020 - val_mean_absolute_error: 0.0323
# Epoch 75/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.1638e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0019 - val_mean_absolute_error: 0.0326
# Epoch 76/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.1194e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0018 - val_mean_absolute_error: 0.0289
# Epoch 77/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.0905e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0011 - val_mean_absolute_error: 0.0208
# Epoch 78/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1621e-04 - mean_absolute_error: 0.0076 - val_loss: 9.1652e-04 - val_mean_absolute_error: 0.0194
# Epoch 79/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2114e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0021 - val_mean_absolute_error: 0.0359
# Epoch 80/100
# 28/28 [==============================] - 3s 96ms/step - loss: 1.0523e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0014 - val_mean_absolute_error: 0.0238
# Epoch 81/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.1536e-04 - mean_absolute_error: 0.0077 - val_loss: 8.7475e-04 - val_mean_absolute_error: 0.0190
# Epoch 82/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.1841e-04 - mean_absolute_error: 0.0077 - val_loss: 8.8065e-04 - val_mean_absolute_error: 0.0189
# Epoch 83/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.0990e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0017 - val_mean_absolute_error: 0.0287
# Epoch 84/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.0584e-04 - mean_absolute_error: 0.0074 - val_loss: 7.8252e-04 - val_mean_absolute_error: 0.0182
# Epoch 85/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2029e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0012 - val_mean_absolute_error: 0.0230
# Epoch 86/100
# 28/28 [==============================] - 2s 65ms/step - loss: 1.0211e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0019 - val_mean_absolute_error: 0.0304
# Epoch 87/100
# 28/28 [==============================] - 3s 97ms/step - loss: 1.0126e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0014 - val_mean_absolute_error: 0.0256
# Epoch 88/100
# 28/28 [==============================] - 2s 64ms/step - loss: 9.6988e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 89/100
# 28/28 [==============================] - 2s 62ms/step - loss: 9.8322e-05 - mean_absolute_error: 0.0069 - val_loss: 8.7898e-04 - val_mean_absolute_error: 0.0191
# Epoch 90/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.0071e-04 - mean_absolute_error: 0.0071 - val_loss: 9.5477e-04 - val_mean_absolute_error: 0.0219
# Epoch 91/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1668e-04 - mean_absolute_error: 0.0077 - val_loss: 8.1939e-04 - val_mean_absolute_error: 0.0185
# Epoch 92/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.0167e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0014 - val_mean_absolute_error: 0.0281
# Epoch 93/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.0106e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0013 - val_mean_absolute_error: 0.0226
# Epoch 94/100
# 28/28 [==============================] - 3s 93ms/step - loss: 1.0116e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0010 - val_mean_absolute_error: 0.0225
# Epoch 95/100
# 28/28 [==============================] - 2s 65ms/step - loss: 1.0869e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0015 - val_mean_absolute_error: 0.0265
# Epoch 96/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.0258e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0017 - val_mean_absolute_error: 0.0254
# Epoch 97/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2668e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0018 - val_mean_absolute_error: 0.0325
# Epoch 98/100
# 28/28 [==============================] - 2s 64ms/step - loss: 9.4808e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0014 - val_mean_absolute_error: 0.0243
# Epoch 99/100
# 28/28 [==============================] - 2s 62ms/step - loss: 9.7177e-05 - mean_absolute_error: 0.0069 - val_loss: 9.2542e-04 - val_mean_absolute_error: 0.0212
# Epoch 100/100
# 28/28 [==============================] - 2s 83ms/step - loss: 9.7131e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0014 - val_mean_absolute_error: 0.0256

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 2s 29ms/step
# array([[0.40157908, 0.40733683],
#        [0.3987567 , 0.4047867 ],
#        [0.3940445 , 0.40007922],
#        [0.40193364, 0.40736282],
#        [0.4046146 , 0.41004246]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1415.4955, 1423.1937],
#        [1410.263 , 1418.4674],
#        [1401.5269, 1409.7428],
#        [1416.1527, 1423.2418],
#        [1421.123 , 1428.2081]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1415.495483      1423.193726
# 2020-05-28  1396.86  1416.73     1410.262939      1418.467407
# 2020-05-29  1416.94  1428.92     1401.526855      1409.742798
# 2020-06-01  1418.39  1431.82     1416.152710      1423.241821
# 2020-06-02  1430.55  1439.22     1421.123047      1428.208130

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()


df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2463.713135      2283.912354
# 2021-06-10  2494.01  2521.60     2472.677979      2289.393799
# 2021-06-11  2524.92  2513.93     2494.403809      2305.543213
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
